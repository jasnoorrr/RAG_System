# %%
import sys
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

print(sys.version)

os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"

print("Libraries loaded successfully")
model = SentenceTransformer("all-MiniLM-L6-v2")
print("Model loaded")
# Out:
# 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# Libraries loaded successfully
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 900.81it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded

# %%
# =========================================
# 1. LOAD AND FILTER DATASET
# =========================================

# Validate dataset exists
dataset_path = "News_Category_Dataset_v3.json"
if not os.path.exists(dataset_path):
    raise FileNotFoundError(
        f"Dataset '{dataset_path}' not found.\n"
        "Download from: https://www.kaggle.com/datasets/rmisra/news-category-dataset\n"
        "Place in current working directory."
    )

# Load dataset
df = pd.read_json(dataset_path, lines=True)
print(f"✓ Loaded {len(df)} documents")

df["text"] = (
    df["headline"].fillna("") + " " +
    df["short_description"].fillna("")
).str.strip()

df = df[df["text"].str.len() > 0]
print(f"Documents with text: {len(df)}")

# Define clean_text function
def clean_text(s: str) -> str:
    s = s.lower()
    s = re.sub(r"[^a-z0-9\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

print("✓ Text column created successfully")
# Out:
# ✓ Loaded 209527 documents
# Documents with text: 209522
# ✓ Text column created successfully

# %%
# =========================================
# 2. FAST SEMANTIC FILTERING
#    (KEYWORD PREFILTER -> SEMANTIC FILTER -> SAMPLE)
# =========================================

# Step 1: broad keyword prefilter
candidate_df = df[df["text"].str.contains(
    r"\b(?:ai|artificial intelligence|machine learning|data science|deep learning|neural network|algorithm|nlp|robotics|automation|computer vision|language model)\b",
    case=False,
    na=False,
    regex=True
)].copy()

print("Candidate docs after keyword prefilter:", len(candidate_df))

# Step 2: semantic topic descriptions
topic_descriptions = [
    "articles about artificial intelligence machine learning deep learning neural networks data science intelligent systems and automation",
    "news about AI research machine learning applications natural language processing computer vision robotics and predictive models",
    "content focused on artificial intelligence technology machine learning methods AI software data science innovation and algorithms"
]

candidate_texts = candidate_df["text"].tolist()

candidate_embeddings = model.encode(
    candidate_texts,
    normalize_embeddings=True,
    show_progress_bar=True,
    batch_size=64
)

topic_embeddings = model.encode(
    topic_descriptions,
    normalize_embeddings=True,
    show_progress_bar=False
)

topic_vector = np.mean(topic_embeddings, axis=0)
topic_vector = topic_vector / np.linalg.norm(topic_vector)

semantic_scores = candidate_embeddings @ topic_vector
candidate_df["semantic_ai_score"] = semantic_scores

# Step 3: Cap for speed (AFTER semantic scores computed)
MAX_CANDIDATES = 5000
if len(candidate_df) > MAX_CANDIDATES:
    candidate_df = candidate_df.nlargest(MAX_CANDIDATES, "semantic_ai_score").copy()

print("Candidate docs used for semantic filtering:", len(candidate_df))

# Step 4: Analyze threshold sensitivity
print("\nThreshold sensitivity analysis:")
for threshold in [0.25, 0.30, 0.35, 0.40, 0.45]:
    n = len(candidate_df[candidate_df["semantic_ai_score"] >= threshold])
    print(f"  Threshold {threshold}: {n:5d} documents")

# Step 5: Apply threshold
SIM_THRESHOLD = 0.35
ai_df = candidate_df[candidate_df["semantic_ai_score"] >= SIM_THRESHOLD].copy()
if len(ai_df) == 0:
    raise ValueError("No documents found after semantic filtering. Try lowering SIM_THRESHOLD.")

print("Semantically filtered AI docs:", len(ai_df))

print("\nTop semantic matches:")
for _, row in ai_df.nlargest(10, "semantic_ai_score")[["text", "semantic_ai_score"]].iterrows():
    print(f"{row['semantic_ai_score']:.4f} | {row['text'][:180]}")

N_DOCS = min(1000, len(ai_df))
docs_clean_raw = ai_df["text"].sample(n=N_DOCS, random_state=42).tolist()

print(f"\nFinal selected docs: {len(docs_clean_raw)}")
# Out:
# Candidate docs after keyword prefilter: 89
# Batches: 100%|██████████| 2/2 [00:01<00:00,  1.76it/s]
# Candidate docs used for semantic filtering: 89
#
# Threshold sensitivity analysis:
#   Threshold 0.25:    54 documents
#   Threshold 0.3:    42 documents
#   Threshold 0.35:    37 documents
#   Threshold 0.4:    20 documents
#   Threshold 0.45:    14 documents
# Semantically filtered AI docs: 37
#
# Top semantic matches:
# 0.5768 | Artificial Intelligence Is Here To Help Us, Microsoft Boss Jean-Philippe Courtois Says "We can augment human capabilities and impact."
# 0.5610 | How To Stop Worrying And Love Artificial Intelligence A new book finds the heart in our cold, robotic future.
# 0.5396 | Artificial Intelligence Is Here To Change Your Life The revolution began before you even realized it.
# 0.5178 | Artificial Intelligence Technology Is 'Breaking Out of the Box' "The exponential improvement in the elements of computing is not about to run out of gas. We've got generations more
# 0.5114 | In a Huge Breakthrough, Google’s AI Beats a Top Player at the Game of Go IN A MAJOR breakthrough for artificial intelligence, a computing system developed by Google researchers in
# 0.5076 | How AI Will Redefine Love Artificial intelligence is beginning to disrupt entire industries from finance to medicine. Yet the most revolutionary application
# 0.5064 | Amazon Is Making It Easier For Companies To Track You By Adrienne LaFrance Like “big data” and “social media” before it, the term “artificial intelligence” has become so buzzworthy
# 0.4672 | AI Day Will Replace Christmas as the Most Important Holiday in Less Than 25 Years Some religious people, anti-transhumanists, and neo-Luddites complain that an advanced AI will des
# 0.4662 | World's Business Elite Are Stressed About Our Robotic Future In Davos, not everyone is excited about artificial intelligence.
# 0.4642 | AI Predicts Autism Based On Infant Brain Scans “It was extremely accurate."
#
# Final selected docs: 37

# %%
# =========================================
# 3. REAL CORPUS PREPARATION (NO MANUAL BLOCKERS)
# =========================================

# Clean the sampled real documents only
docs_clean = [clean_text(d) for d in docs_clean_raw]

print("Clean docs:", len(docs_clean))
print("Manual blockers removed.")
print("We will use real hard negatives (distractors) from the dataset instead of fake blockers.")

# Keep a mapping from local sampled index -> original sampled text
doc_id_map = list(range(len(docs_clean)))

# Helper: identify hard negatives for a query from the REAL corpus
def get_hard_negatives(query, docs, doc_emb, gold_idx, top_n=10):
    q = clean_text(query)
    q_emb = model.encode([q], normalize_embeddings=True)[0]
    scores = doc_emb @ q_emb
    ranked_idx = np.argsort(-scores)

    hard_negatives = []
    for idx in ranked_idx:
        idx = int(idx)
        if idx != gold_idx:
            hard_negatives.append((idx, docs[idx], float(scores[idx])))
        if len(hard_negatives) >= top_n:
            break

    return hard_negatives

# Helper: count distractors in top-k results
# Since all non-gold retrieved docs are distractors in this setup,
# we count how many of the top-k are not the gold document.
def count_distractors(results, gold_idx):
    return sum(1 for idx, _, _ in results if idx != gold_idx)
# Out:
# Clean docs: 37
# Manual blockers removed.
# We will use real hard negatives (distractors) from the dataset instead of fake blockers.

# %%
# =========================================
# 4. QUERY-GOLD PAIRS (MANUAL REALISTIC QUERIES)
# =========================================

# IMPORTANT:
# These queries are written to sound like real user questions.
# Each query is manually mapped to a gold document index from the sampled corpus.
# If your sampled corpus changes, these indices must be checked again.

print("\nSampled corpus preview (index -> document):")
for i, doc in enumerate(docs_clean):
    print(f"[{i}] {doc[:140]}...")

# Manually chosen query-gold pairs based on the current sampled corpus output.
# These are written to be semantically related, not copied directly from the document.
query_gold_pairs = [
    ("why are business leaders worried about artificial intelligence", 7),
    ("can artificial intelligence predict autism in babies", 14),
    ("why do siri and other digital assistants use female voices", 22),
    ("what is facebook doing to build an artificial brain", 29),
    ("how is microsoft describing the benefits of artificial intelligence", 5),
    ("how is artificial intelligence expected to change daily life", 1),
    ("what breakthrough did google make in the game of go using ai", 8),
    ("how could ai change love and relationships", 9),
    ("why is artificial intelligence technology said to be breaking out of the box", 17),
    ("what does big data have to do with artificial intelligence hype", 30),
]

# Safety check: make sure indices exist in the sampled corpus
for query, gold_idx in query_gold_pairs:
    if gold_idx < 0 or gold_idx >= len(docs_clean):
        raise ValueError(f"Gold index {gold_idx} is out of range for query: {query}")

print("\nQuery-gold pairs:")
for q, idx in query_gold_pairs:
    print(f"Query: {q} -> Gold doc index: {idx}")
    print(f"Gold doc preview: {docs_clean[idx][:120]}...")
    print()
    print("Please verify that each query matches the gold preview above before running the full evaluation.")

print(f"Total query-gold pairs: {len(query_gold_pairs)}")

# Human-readable evaluation queries
queries = [q for q, _ in query_gold_pairs]
print("Evaluation queries loaded:", len(queries))
# Out:
# Sampled corpus preview (index -> document):
# [0] human player finally beats google s alphago ai program at go it was fourth time lucky for lee sedol...
# [1] this groundbreaking algorithm can spot sepsis before doctors five ways artificial intelligence can improve our lives...
# [2] we should make ai and blockchain boost global trade it is time to build an intelligent tech and trade initiative...
# [3] toyota makes major investment in artificial intelligence the japanese automaker is pouring 1 billion into new research that could bring self...
# [4] preparing to live in that unknown country the future are google s driverless car and siri just the beginning for applied machine intelligenc...
# [5] artificial intelligence is here to help us microsoft boss jean philippe courtois says we can augment human capabilities and impact...
# [6] leaders of top robotics and ai companies call for ban on killer robots elon musk and others have signed an open letter warning about autonom...
# [7] world s business elite are stressed about our robotic future in davos not everyone is excited about artificial intelligence...
# [8] in a huge breakthrough google s ai beats a top player at the game of go in a major breakthrough for artificial intelligence a computing syst...
# [9] how ai will redefine love artificial intelligence is beginning to disrupt entire industries from finance to medicine yet the most revolution...
# [10] what your data scientist wishes you knew by daniel wesley big data it s the topic on everyone s lips even high schoolers are clamoring to ge...
# [11] will letting ai make our decisions be the best decision we make i confess while writing this i was intermittently procrastinating by browsin...
# [12] why automation will create not destroy jobs if you have been watching political tectonics on both sides of the atlantic you may have noticed...
# [13] the rise of the wisdom worker conventional wisdom has it that the knowledge worker will reign supreme well into the 21st century the thing i...
# [14] ai predicts autism based on infant brain scans it was extremely accurate...
# [15] artificial intelligence is here to change your life the revolution began before you even realized it...
# [16] jimmy fallon duetted with sophia the robot and it got a bit weird the tonight show host sang a great big world s say something with the ai h...
# [17] artificial intelligence technology is breaking out of the box the exponential improvement in the elements of computing is not about to run o...
# [18] ai weiwei nationality and borders are barriers to our intelligence and imagination the worldpost sat down with ai to discuss his new documen...
# [19] is an ai arms race inevitable unlike nuclear weapons this new class can potentially target by traits like race or even by what people have l...
# [20] machines don t always steal our jobs increasingly they rob our work of humanity your next boss could be an algorithm...
# [21] robots will replace 5 million workers by 2020 report automation promises to make many administrative tasks redundant which could hurt women ...
# [22] why are digital assistants like siri given female voices at an artificial intelligence conference a good question gets a surprising answer...
# [23] will smith s date with sophia the ai robot ends firmly in the friend zone i ve heard your songs not for me...
# [24] alan turing s brother he should be alive today june 23rd is the centenary of the birth of alan turing father of computer science and artific...
# [25] big data and deep learning big deals or big delusions getting the most out deep learning will require deep thinking that s where authentic h...
# [26] this ai robot shading chrissy teigen makes us fear for humanity it was nice knowing you chrissy...
# [27] ai day will replace christmas as the most important holiday in less than 25 years some religious people anti transhumanists and neo luddites...
# [28] how google s ai beat a human at go a decade earlier than expected last week news broke that the holy grail of game playing ai the ancient an...
# [29] inside facebook s plan to build an artificial brain the beauty of ai systems is that we can get enough scale to deploy this to everyone on t...
# [30] amazon is making it easier for companies to track you by adrienne lafrance like big data and social media before it the term artificial inte...
# [31] how to stop worrying and love artificial intelligence a new book finds the heart in our cold robotic future...
# [32] google s alphago ai program defeats one of world s best go players this is huge...
# [33] artificial intelligence might just disrupt know it all white men robots will likely terminate at least one aspect of male privilege in busin...
# [34] how ai robots hunt new drugs for crippling nerve disease als attacks and kills nerve cells controlling muscles leading to weakness paralysis...
# [35] will automation upend journalism...
# [36] google just open sourced its artificial intelligence engine tech pundit tim o reilly had just tried the new google photos app and he was ama...
#
# Query-gold pairs:
# Query: why are business leaders worried about artificial intelligence -> Gold doc index: 7
# Gold doc preview: world s business elite are stressed about our robotic future in davos not everyone is excited about artificial intellige...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: can artificial intelligence predict autism in babies -> Gold doc index: 14
# Gold doc preview: ai predicts autism based on infant brain scans it was extremely accurate...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: why do siri and other digital assistants use female voices -> Gold doc index: 22
# Gold doc preview: why are digital assistants like siri given female voices at an artificial intelligence conference a good question gets a...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: what is facebook doing to build an artificial brain -> Gold doc index: 29
# Gold doc preview: inside facebook s plan to build an artificial brain the beauty of ai systems is that we can get enough scale to deploy t...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: how is microsoft describing the benefits of artificial intelligence -> Gold doc index: 5
# Gold doc preview: artificial intelligence is here to help us microsoft boss jean philippe courtois says we can augment human capabilities ...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: how is artificial intelligence expected to change daily life -> Gold doc index: 1
# Gold doc preview: this groundbreaking algorithm can spot sepsis before doctors five ways artificial intelligence can improve our lives...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: what breakthrough did google make in the game of go using ai -> Gold doc index: 8
# Gold doc preview: in a huge breakthrough google s ai beats a top player at the game of go in a major breakthrough for artificial intellige...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: how could ai change love and relationships -> Gold doc index: 9
# Gold doc preview: how ai will redefine love artificial intelligence is beginning to disrupt entire industries from finance to medicine yet...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: why is artificial intelligence technology said to be breaking out of the box -> Gold doc index: 17
# Gold doc preview: artificial intelligence technology is breaking out of the box the exponential improvement in the elements of computing i...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Query: what does big data have to do with artificial intelligence hype -> Gold doc index: 30
# Gold doc preview: amazon is making it easier for companies to track you by adrienne lafrance like big data and social media before it the ...
#
# Please verify that each query matches the gold preview above before running the full evaluation.
# Total query-gold pairs: 10
# Evaluation queries loaded: 10

# %%
# =========================================
# 5. BUILD REAL CORPUS AND EMBEDDINGS
# =========================================

# We now work with one real corpus only.
# There is no attacked corpus made by appending manual blockers.
# Distractors will come naturally from other real documents in this corpus.

docs_corpus = docs_clean

doc_emb_corpus = model.encode(docs_corpus, normalize_embeddings=True)

print("Corpus size:", len(docs_corpus))
print("Corpus embeddings shape:", doc_emb_corpus.shape)
print("Using one real corpus only (no manual blocker injection).")
# Out:
# Corpus size: 37
# Corpus embeddings shape: (37, 384)
# Using one real corpus only (no manual blocker injection).

# %%
# =========================================
# 6. SPARSE INDEXES
# =========================================

tokenized_corpus = [doc.split() for doc in docs_corpus]

bm25_corpus = BM25Okapi(tokenized_corpus)

tfidf_vectorizer = TfidfVectorizer(stop_words="english")
tfidf_matrix_corpus = tfidf_vectorizer.fit_transform(docs_corpus)

print("BM25 ready")
print("TF-IDF ready")
print("Sparse indexes built on the real corpus only.")
# Out:
# BM25 ready
# TF-IDF ready
# Sparse indexes built on the real corpus only.

# %%
# =========================================
# 7. RETRIEVAL FUNCTIONS
# =========================================

def retrieve_topk_precomputed(query, docs, doc_emb, k=5):
    k = min(k, len(docs))
    q = clean_text(query)
    q_emb = model.encode([q], normalize_embeddings=True)[0]
    scores = doc_emb @ q_emb
    top_idx = np.argsort(-scores)[:k]
    return [(int(i), docs[int(i)], float(scores[int(i)])) for i in top_idx]

def retrieve_bm25(query, docs, bm25, k=5):
    k = min(k, len(docs))
    tokenized_query = clean_text(query).split()
    scores = bm25.get_scores(tokenized_query)
    top_idx = np.argsort(scores)[::-1][:k]
    return [(int(i), docs[int(i)], float(scores[int(i)])) for i in top_idx]

def retrieve_tfidf(query, docs, tfidf_matrix, vectorizer, k=5):
    k = min(k, len(docs))
    q_vec = vectorizer.transform([clean_text(query)])
    scores = cosine_similarity(q_vec, tfidf_matrix)[0]
    top_idx = scores.argsort()[::-1][:k]
    return [(int(i), docs[int(i)], float(scores[int(i)])) for i in top_idx]

def retrieve_hybrid(query, docs, doc_emb, bm25, k=5, alpha=0.5):
    k = min(k, len(docs))
    q_emb = model.encode([clean_text(query)], normalize_embeddings=True)[0]
    dense_scores = doc_emb @ q_emb
    tokenized_query = clean_text(query).split()
    bm25_scores = bm25.get_scores(tokenized_query)

    dense_scores = np.array(dense_scores)
    bm25_scores = np.array(bm25_scores)

    dense_norm = (dense_scores - dense_scores.min()) / (dense_scores.max() - dense_scores.min() + 1e-8)
    bm25_norm = (bm25_scores - bm25_scores.min()) / (bm25_scores.max() - bm25_scores.min() + 1e-8)

    hybrid_scores = alpha * dense_norm + (1 - alpha) * bm25_norm

    top_idx = np.argsort(hybrid_scores)[::-1][:k]
    return [(int(i), docs[int(i)], float(hybrid_scores[int(i)])) for i in top_idx]

# %%
# =========================================
# 7.5 GENERICNESS SCORE FOR DEFENSE
# =========================================

GENERIC_TERMS = {
    "system", "systems", "model", "models",
    "performance", "methods", "general",
    "concepts", "overview", "analysis"
}

def genericness_score(doc: str):
    tokens = clean_text(doc).split()
    if not tokens:
        return 0.0
    generic_hits = sum(1 for t in tokens if t in GENERIC_TERMS)
    return generic_hits / len(tokens)

# %%
# =========================================
# 7.6 DEFENDED DENSE RETRIEVAL
# =========================================

def retrieve_defended_dense(
    query,
    docs,
    doc_emb,
    bm25,
    tfidf_matrix,
    tfidf_vectorizer,
    top_n=20,
    k=5,
    alpha_dense=0.6,
    alpha_bm25=0.25,
    alpha_tfidf=0.15,
    generic_penalty_weight=0.05
):
    q = clean_text(query)

    # Step 1: Dense retrieval for top candidates
    q_emb = model.encode([q], normalize_embeddings=True)[0]
    dense_scores = doc_emb @ q_emb
    candidate_idx = np.argsort(-dense_scores)[:min(top_n, len(docs))]

    # Step 2: BM25 scores on whole corpus
    bm25_scores = np.array(bm25.get_scores(q.split()))

    # Step 3: TF-IDF scores on whole corpus
    q_vec = tfidf_vectorizer.transform([q])
    tfidf_scores = cosine_similarity(q_vec, tfidf_matrix)[0]

    # Step 4: Normalize candidate scores
    d = dense_scores[candidate_idx]
    b = bm25_scores[candidate_idx]
    t = tfidf_scores[candidate_idx]

    d_norm = (d - d.min()) / (d.max() - d.min() + 1e-8)
    b_norm = (b - b.min()) / (b.max() - b.min() + 1e-8)
    t_norm = (t - t.min()) / (t.max() - t.min() + 1e-8)

    final_results = []

    for local_i, global_i in enumerate(candidate_idx):
        doc = docs[int(global_i)]
        penalty = generic_penalty_weight * genericness_score(doc)

        final_score = (
            alpha_dense * d_norm[local_i]
            + alpha_bm25 * b_norm[local_i]
            + alpha_tfidf * t_norm[local_i]
            - penalty
        )

        final_results.append((int(global_i), doc, float(final_score)))

    final_results.sort(key=lambda x: x[2], reverse=True)
    return final_results[:k]

# %%
# =========================================
# 8. HELPER FUNCTIONS FOR RANKING AND METRICS
# =========================================

def get_rank_of_doc(results, target_idx):
    for rank, (idx, _, _) in enumerate(results, start=1):
        if idx == target_idx:
            return rank
    return None

def hit_at_k(rank, k):
    return 1 if rank is not None and rank <= k else 0

def reciprocal_rank(rank):
    return 1.0 / rank if rank is not None else 0.0

def count_distractors_above_gold(results, gold_idx):
    """
    Count how many retrieved documents appear before the gold document.
    If gold is rank 1, this returns 0.
    If gold is rank 4, this returns 3.
    If gold is missing from results, return len(results).
    """
    count = 0
    for idx, _, _ in results:
        if idx == gold_idx:
            return count
        count += 1
    return len(results)

def evaluate_single_method(query_gold_pairs, retrieve_fn, k=10):
    hits = []
    rrs = []
    distractors_above_gold = []

    for query, gold_idx in query_gold_pairs:
        results = retrieve_fn(query)
        rank = get_rank_of_doc(results, gold_idx)

        hits.append(hit_at_k(rank, k))
        rrs.append(reciprocal_rank(rank))
        distractors_above_gold.append(count_distractors_above_gold(results, gold_idx))

    return {
        "Hit@10": np.mean(hits),
        "MRR@10": np.mean(rrs),
        "Avg Distractors Above Gold": np.mean(distractors_above_gold),
    }

# %%
# =========================================
# 9. BASIC DENSE BASELINE VS DEFENSE EXAMPLE
# =========================================

K_DISTRACTOR_ANALYSIS = 5   # For qualitative inspection
K_EVALUATION = 10           # For retrieval metrics

example_query = query_gold_pairs[0][0]
example_gold_idx = query_gold_pairs[0][1]

print("===== DENSE BASELINE RESULTS =====")
baseline_results = retrieve_topk_precomputed(
    example_query, docs_corpus, doc_emb_corpus, K_DISTRACTOR_ANALYSIS
)
for idx, text, score in baseline_results:
    tag = "GOLD" if idx == example_gold_idx else "DISTRACTOR"
    print(f"[{idx}] {tag} score={score:.4f} | {text[:120]}...")

baseline_rank = get_rank_of_doc(baseline_results, example_gold_idx)
baseline_above_gold = count_distractors_above_gold(baseline_results, example_gold_idx)
print(f"\nGold rank in Dense: {baseline_rank}")
print(f"Distractors above gold in top-{K_DISTRACTOR_ANALYSIS}: {baseline_above_gold}")

print("\n===== DEFENDED DENSE RESULTS =====")
defended_results = retrieve_defended_dense(
    example_query,
    docs_corpus,
    doc_emb_corpus,
    bm25_corpus,
    tfidf_matrix_corpus,
    tfidf_vectorizer,
    top_n=20,
    k=K_DISTRACTOR_ANALYSIS
)
for idx, text, score in defended_results:
    tag = "GOLD" if idx == example_gold_idx else "DISTRACTOR"
    print(f"[{idx}] {tag} score={score:.4f} | {text[:120]}...")

defended_rank = get_rank_of_doc(defended_results, example_gold_idx)
defended_above_gold = count_distractors_above_gold(defended_results, example_gold_idx)
print(f"\nGold rank in Defended Dense: {defended_rank}")
print(f"Distractors above gold in top-{K_DISTRACTOR_ANALYSIS}: {defended_above_gold}")
# =========================================
# 10. QUALITATIVE EVALUATION QUERIES
# =========================================

print("Queries loaded:", len(queries))
for i, q in enumerate(queries, start=1):
    print(f"Q{i}: {q}")

# =========================================
# 11. DENSE DISTRACTOR DOMINANCE
# =========================================

dense_distractor_counts = []

for query, gold_idx in query_gold_pairs:
    results = retrieve_topk_precomputed(
        query, docs_corpus, doc_emb_corpus, K_DISTRACTOR_ANALYSIS
    )
    hits = count_distractors_above_gold(results, gold_idx)
    dense_distractor_counts.append(hits)

plt.figure()
plt.bar(range(len(query_gold_pairs)), dense_distractor_counts)
plt.xticks(range(len(query_gold_pairs)), [f"Q{i+1}" for i in range(len(query_gold_pairs))])
plt.ylim(0, K_DISTRACTOR_ANALYSIS)
plt.xlabel("Queries")
plt.ylabel("Distractors Above Gold")
plt.title("Dense Retrieval: Distractors Ranked Above Gold")
plt.show()
# Out:
# ===== DENSE BASELINE RESULTS =====
# [7] GOLD score=0.6479 | world s business elite are stressed about our robotic future in davos not everyone is excited about artificial intellige...
# [33] DISTRACTOR score=0.5879 | artificial intelligence might just disrupt know it all white men robots will likely terminate at least one aspect of mal...
# [17] DISTRACTOR score=0.5875 | artificial intelligence technology is breaking out of the box the exponential improvement in the elements of computing i...
# [30] DISTRACTOR score=0.5712 | amazon is making it easier for companies to track you by adrienne lafrance like big data and social media before it the ...
# [5] DISTRACTOR score=0.5605 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we can augment human capabilities ...
#
# Gold rank in Dense: 1
# Distractors above gold in top-5: 0
#
# ===== DEFENDED DENSE RESULTS =====
# [7] GOLD score=1.0000 | world s business elite are stressed about our robotic future in davos not everyone is excited about artificial intellige...
# [33] DISTRACTOR score=0.6524 | artificial intelligence might just disrupt know it all white men robots will likely terminate at least one aspect of mal...
# [17] DISTRACTOR score=0.5316 | artificial intelligence technology is breaking out of the box the exponential improvement in the elements of computing i...
# [12] DISTRACTOR score=0.4339 | why automation will create not destroy jobs if you have been watching political tectonics on both sides of the atlantic ...
# [30] DISTRACTOR score=0.4256 | amazon is making it easier for companies to track you by adrienne lafrance like big data and social media before it the ...
#
# Gold rank in Defended Dense: 1
# Distractors above gold in top-5: 0
# Queries loaded: 10
# Q1: why are business leaders worried about artificial intelligence
# Q2: can artificial intelligence predict autism in babies
# Q3: why do siri and other digital assistants use female voices
# Q4: what is facebook doing to build an artificial brain
# Q5: how is microsoft describing the benefits of artificial intelligence
# Q6: how is artificial intelligence expected to change daily life
# Q7: what breakthrough did google make in the game of go using ai
# Q8: how could ai change love and relationships
# Q9: why is artificial intelligence technology said to be breaking out of the box
# Q10: what does big data have to do with artificial intelligence hype

# %%
# =========================================
# 12. BM25 DISTRACTOR ANALYSIS
# =========================================

print("===== BM25 RESULTS =====")

for query, gold_idx in query_gold_pairs:
    print("\nQuery:", query)

    results = retrieve_bm25(query, docs_corpus, bm25_corpus, k=K_DISTRACTOR_ANALYSIS)
    distractor_hits = count_distractors_above_gold(results, gold_idx)
    gold_rank = get_rank_of_doc(results, gold_idx)

    print(f"  Gold rank: {gold_rank}")
    print(f"  Distractors above gold: {distractor_hits}")

    for idx, text, score in results:
        tag = "GOLD" if idx == gold_idx else "DISTRACTOR"
        print(f"  - [{idx}] {tag} score={score:.4f} | {text[:90]}...")

# =========================================
# 13. TF-IDF DISTRACTOR ANALYSIS
# =========================================

print("===== TF-IDF RESULTS =====")

for query, gold_idx in query_gold_pairs:
    print("\nQuery:", query)

    results = retrieve_tfidf(
        query, docs_corpus, tfidf_matrix_corpus, tfidf_vectorizer, k=K_DISTRACTOR_ANALYSIS
    )
    distractor_hits = count_distractors_above_gold(results, gold_idx)
    gold_rank = get_rank_of_doc(results, gold_idx)

    print(f"  Gold rank: {gold_rank}")
    print(f"  Distractors above gold: {distractor_hits}")

    for idx, text, score in results:
        tag = "GOLD" if idx == gold_idx else "DISTRACTOR"
        print(f"  - [{idx}] {tag} score={score:.4f} | {text[:90]}...")

# =========================================
# 14. HYBRID DISTRACTOR ANALYSIS
# =========================================

print("===== HYBRID RESULTS =====")

for query, gold_idx in query_gold_pairs:
    print("\nQuery:", query)

    results = retrieve_hybrid(
        query, docs_corpus, doc_emb_corpus, bm25_corpus, k=K_DISTRACTOR_ANALYSIS, alpha=0.5
    )
    distractor_hits = count_distractors_above_gold(results, gold_idx)
    gold_rank = get_rank_of_doc(results, gold_idx)

    print(f"  Gold rank: {gold_rank}")
    print(f"  Distractors above gold: {distractor_hits}")

    for idx, text, score in results:
        tag = "GOLD" if idx == gold_idx else "DISTRACTOR"
        print(f"  - [{idx}] {tag} score={score:.4f} | {text[:90]}...")

# =========================================
# 14.5 DEFENDED DENSE DISTRACTOR ANALYSIS
# =========================================

print("===== DEFENDED DENSE RESULTS =====")

for query, gold_idx in query_gold_pairs:
    print("\nQuery:", query)

    results = retrieve_defended_dense(
        query,
        docs_corpus,
        doc_emb_corpus,
        bm25_corpus,
        tfidf_matrix_corpus,
        tfidf_vectorizer,
        top_n=20,
        k=K_DISTRACTOR_ANALYSIS
    )
    distractor_hits = count_distractors_above_gold(results, gold_idx)
    gold_rank = get_rank_of_doc(results, gold_idx)

    print(f"  Gold rank: {gold_rank}")
    print(f"  Distractors above gold: {distractor_hits}")

    for idx, text, score in results:
        tag = "GOLD" if idx == gold_idx else "DISTRACTOR"
        print(f"  - [{idx}] {tag} score={score:.4f} | {text[:90]}...")
# Out:
# ===== BM25 RESULTS =====
#
# Query: why are business leaders worried about artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [7] GOLD score=7.6054 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [6] DISTRACTOR score=5.1075 | leaders of top robotics and ai companies call for ban on killer robots elon musk and other...
#   - [22] DISTRACTOR score=4.6087 | why are digital assistants like siri given female voices at an artificial intelligence con...
#   - [12] DISTRACTOR score=3.8771 | why automation will create not destroy jobs if you have been watching political tectonics ...
#   - [18] DISTRACTOR score=3.1076 | ai weiwei nationality and borders are barriers to our intelligence and imagination the wor...
#
# Query: can artificial intelligence predict autism in babies
#   Gold rank: 1
#   Distractors above gold: 0
#   - [14] GOLD score=4.2837 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [1] DISTRACTOR score=3.5780 | this groundbreaking algorithm can spot sepsis before doctors five ways artificial intellig...
#   - [5] DISTRACTOR score=2.5347 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [29] DISTRACTOR score=2.1200 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [19] DISTRACTOR score=1.9652 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
#
# Query: why do siri and other digital assistants use female voices
#   Gold rank: 1
#   Distractors above gold: 0
#   - [22] GOLD score=20.2746 | why are digital assistants like siri given female voices at an artificial intelligence con...
#   - [12] DISTRACTOR score=2.6393 | why automation will create not destroy jobs if you have been watching political tectonics ...
#   - [17] DISTRACTOR score=2.6141 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [4] DISTRACTOR score=2.3426 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [2] DISTRACTOR score=0.5845 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#
# Query: what is facebook doing to build an artificial brain
#   Gold rank: 1
#   Distractors above gold: 0
#   - [29] GOLD score=11.4123 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [2] DISTRACTOR score=5.9964 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#   - [19] DISTRACTOR score=4.1966 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
#   - [14] DISTRACTOR score=3.5608 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [10] DISTRACTOR score=2.7363 | what your data scientist wishes you knew by daniel wesley big data it s the topic on every...
#
# Query: how is microsoft describing the benefits of artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [5] GOLD score=4.5689 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [9] DISTRACTOR score=3.6573 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=3.1711 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [28] DISTRACTOR score=2.5960 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [4] DISTRACTOR score=2.3318 | preparing to live in that unknown country the future are google s driverless car and siri ...
#
# Query: how is artificial intelligence expected to change daily life
#   Gold rank: None
#   Distractors above gold: 5
#   - [15] DISTRACTOR score=8.9463 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [28] DISTRACTOR score=4.2542 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [9] DISTRACTOR score=3.7575 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [3] DISTRACTOR score=3.4985 | toyota makes major investment in artificial intelligence the japanese automaker is pouring...
#   - [31] DISTRACTOR score=3.0076 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#
# Query: what breakthrough did google make in the game of go using ai
#   Gold rank: 1
#   Distractors above gold: 0
#   - [8] GOLD score=13.2103 | in a huge breakthrough google s ai beats a top player at the game of go in a major breakth...
#   - [28] DISTRACTOR score=8.3180 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [11] DISTRACTOR score=4.5652 | will letting ai make our decisions be the best decision we make i confess while writing th...
#   - [32] DISTRACTOR score=4.5314 | google s alphago ai program defeats one of world s best go players this is huge...
#   - [0] DISTRACTOR score=4.0898 | human player finally beats google s alphago ai program at go it was fourth time lucky for ...
#
# Query: how could ai change love and relationships
#   Gold rank: 2
#   Distractors above gold: 1
#   - [31] DISTRACTOR score=5.5911 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [9] GOLD score=5.0544 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [15] DISTRACTOR score=3.9398 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [4] DISTRACTOR score=3.1624 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [34] DISTRACTOR score=2.5319 | how ai robots hunt new drugs for crippling nerve disease als attacks and kills nerve cells...
#
# Query: why is artificial intelligence technology said to be breaking out of the box
#   Gold rank: 1
#   Distractors above gold: 0
#   - [17] GOLD score=12.3842 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [13] DISTRACTOR score=4.1361 | the rise of the wisdom worker conventional wisdom has it that the knowledge worker will re...
#   - [24] DISTRACTOR score=4.0517 | alan turing s brother he should be alive today june 23rd is the centenary of the birth of ...
#   - [3] DISTRACTOR score=3.8740 | toyota makes major investment in artificial intelligence the japanese automaker is pouring...
#   - [12] DISTRACTOR score=3.5293 | why automation will create not destroy jobs if you have been watching political tectonics ...
#
# Query: what does big data have to do with artificial intelligence hype
#   Gold rank: None
#   Distractors above gold: 5
#   - [10] DISTRACTOR score=7.2962 | what your data scientist wishes you knew by daniel wesley big data it s the topic on every...
#   - [25] DISTRACTOR score=6.7456 | big data and deep learning big deals or big delusions getting the most out deep learning w...
#   - [19] DISTRACTOR score=4.4799 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
#   - [17] DISTRACTOR score=4.3827 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [16] DISTRACTOR score=4.3358 | jimmy fallon duetted with sophia the robot and it got a bit weird the tonight show host sa...
# ===== TF-IDF RESULTS =====
#
# Query: why are business leaders worried about artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [7] GOLD score=0.2958 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [33] DISTRACTOR score=0.2390 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#   - [6] DISTRACTOR score=0.1876 | leaders of top robotics and ai companies call for ban on killer robots elon musk and other...
#   - [36] DISTRACTOR score=0.1209 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [15] DISTRACTOR score=0.1130 | artificial intelligence is here to change your life the revolution began before you even r...
#
# Query: can artificial intelligence predict autism in babies
#   Gold rank: 1
#   Distractors above gold: 0
#   - [14] GOLD score=0.3009 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [36] DISTRACTOR score=0.1521 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [15] DISTRACTOR score=0.1422 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [7] DISTRACTOR score=0.1194 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [1] DISTRACTOR score=0.1132 | this groundbreaking algorithm can spot sepsis before doctors five ways artificial intellig...
#
# Query: why do siri and other digital assistants use female voices
#   Gold rank: 1
#   Distractors above gold: 0
#   - [22] GOLD score=0.6158 | why are digital assistants like siri given female voices at an artificial intelligence con...
#   - [4] DISTRACTOR score=0.0729 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [34] DISTRACTOR score=0.0000 | how ai robots hunt new drugs for crippling nerve disease als attacks and kills nerve cells...
#   - [35] DISTRACTOR score=0.0000 | will automation upend journalism...
#   - [36] DISTRACTOR score=0.0000 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#
# Query: what is facebook doing to build an artificial brain
#   Gold rank: 1
#   Distractors above gold: 0
#   - [29] GOLD score=0.5297 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [14] DISTRACTOR score=0.1699 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [2] DISTRACTOR score=0.1371 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#   - [36] DISTRACTOR score=0.0550 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [15] DISTRACTOR score=0.0514 | artificial intelligence is here to change your life the revolution began before you even r...
#
# Query: how is microsoft describing the benefits of artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [5] GOLD score=0.3591 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [36] DISTRACTOR score=0.1521 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [15] DISTRACTOR score=0.1422 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [7] DISTRACTOR score=0.1194 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [1] DISTRACTOR score=0.1132 | this groundbreaking algorithm can spot sepsis before doctors five ways artificial intellig...
#
# Query: how is artificial intelligence expected to change daily life
#   Gold rank: None
#   Distractors above gold: 5
#   - [15] DISTRACTOR score=0.5377 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [3] DISTRACTOR score=0.1694 | toyota makes major investment in artificial intelligence the japanese automaker is pouring...
#   - [28] DISTRACTOR score=0.1254 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [36] DISTRACTOR score=0.1001 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [7] DISTRACTOR score=0.0786 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#
# Query: what breakthrough did google make in the game of go using ai
#   Gold rank: 1
#   Distractors above gold: 0
#   - [8] GOLD score=0.5748 | in a huge breakthrough google s ai beats a top player at the game of go in a major breakth...
#   - [28] DISTRACTOR score=0.3361 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [11] DISTRACTOR score=0.2211 | will letting ai make our decisions be the best decision we make i confess while writing th...
#   - [32] DISTRACTOR score=0.1457 | google s alphago ai program defeats one of world s best go players this is huge...
#   - [2] DISTRACTOR score=0.1408 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#
# Query: how could ai change love and relationships
#   Gold rank: 2
#   Distractors above gold: 1
#   - [15] DISTRACTOR score=0.3104 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [9] GOLD score=0.2239 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=0.1887 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [28] DISTRACTOR score=0.0931 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [18] DISTRACTOR score=0.0788 | ai weiwei nationality and borders are barriers to our intelligence and imagination the wor...
#
# Query: why is artificial intelligence technology said to be breaking out of the box
#   Gold rank: 1
#   Distractors above gold: 0
#   - [17] GOLD score=0.4014 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [3] DISTRACTOR score=0.1545 | toyota makes major investment in artificial intelligence the japanese automaker is pouring...
#   - [13] DISTRACTOR score=0.1240 | the rise of the wisdom worker conventional wisdom has it that the knowledge worker will re...
#   - [36] DISTRACTOR score=0.1022 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#   - [15] DISTRACTOR score=0.0955 | artificial intelligence is here to change your life the revolution began before you even r...
#
# Query: what does big data have to do with artificial intelligence hype
#   Gold rank: 3
#   Distractors above gold: 2
#   - [10] DISTRACTOR score=0.4382 | what your data scientist wishes you knew by daniel wesley big data it s the topic on every...
#   - [25] DISTRACTOR score=0.3703 | big data and deep learning big deals or big delusions getting the most out deep learning w...
#   - [30] GOLD score=0.3370 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#   - [4] DISTRACTOR score=0.2041 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [17] DISTRACTOR score=0.1734 | artificial intelligence technology is breaking out of the box the exponential improvement ...
# ===== HYBRID RESULTS =====
#
# Query: why are business leaders worried about artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [7] GOLD score=1.0000 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [12] DISTRACTOR score=0.6403 | why automation will create not destroy jobs if you have been watching political tectonics ...
#   - [33] DISTRACTOR score=0.6372 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#   - [6] DISTRACTOR score=0.5902 | leaders of top robotics and ai companies call for ban on killer robots elon musk and other...
#   - [17] DISTRACTOR score=0.5800 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#
# Query: can artificial intelligence predict autism in babies
#   Gold rank: 1
#   Distractors above gold: 0
#   - [14] GOLD score=1.0000 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [1] DISTRACTOR score=0.5947 | this groundbreaking algorithm can spot sepsis before doctors five ways artificial intellig...
#   - [29] DISTRACTOR score=0.4697 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [5] DISTRACTOR score=0.4467 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [19] DISTRACTOR score=0.3631 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
#
# Query: why do siri and other digital assistants use female voices
#   Gold rank: 1
#   Distractors above gold: 0
#   - [22] GOLD score=1.0000 | why are digital assistants like siri given female voices at an artificial intelligence con...
#   - [4] DISTRACTOR score=0.2359 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [21] DISTRACTOR score=0.1866 | robots will replace 5 million workers by 2020 report automation promises to make many admi...
#   - [33] DISTRACTOR score=0.1851 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#   - [26] DISTRACTOR score=0.1508 | this ai robot shading chrissy teigen makes us fear for humanity it was nice knowing you ch...
#
# Query: what is facebook doing to build an artificial brain
#   Gold rank: 1
#   Distractors above gold: 0
#   - [29] GOLD score=1.0000 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [2] DISTRACTOR score=0.3931 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#   - [14] DISTRACTOR score=0.3595 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [19] DISTRACTOR score=0.2672 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
#   - [9] DISTRACTOR score=0.2662 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#
# Query: how is microsoft describing the benefits of artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [5] GOLD score=1.0000 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [9] DISTRACTOR score=0.7461 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=0.5886 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [17] DISTRACTOR score=0.5856 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [30] DISTRACTOR score=0.5204 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#
# Query: how is artificial intelligence expected to change daily life
#   Gold rank: None
#   Distractors above gold: 5
#   - [15] DISTRACTOR score=1.0000 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [9] DISTRACTOR score=0.5908 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=0.4989 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [28] DISTRACTOR score=0.4752 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [17] DISTRACTOR score=0.4547 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#
# Query: what breakthrough did google make in the game of go using ai
#   Gold rank: 1
#   Distractors above gold: 0
#   - [8] GOLD score=1.0000 | in a huge breakthrough google s ai beats a top player at the game of go in a major breakth...
#   - [28] DISTRACTOR score=0.8060 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [32] DISTRACTOR score=0.5925 | google s alphago ai program defeats one of world s best go players this is huge...
#   - [0] DISTRACTOR score=0.5169 | human player finally beats google s alphago ai program at go it was fourth time lucky for ...
#   - [36] DISTRACTOR score=0.3721 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#
# Query: how could ai change love and relationships
#   Gold rank: 1
#   Distractors above gold: 0
#   - [9] GOLD score=0.9520 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=0.8036 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [15] DISTRACTOR score=0.6612 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [4] DISTRACTOR score=0.4466 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [28] DISTRACTOR score=0.3792 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#
# Query: why is artificial intelligence technology said to be breaking out of the box
#   Gold rank: 1
#   Distractors above gold: 0
#   - [17] GOLD score=1.0000 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [13] DISTRACTOR score=0.4560 | the rise of the wisdom worker conventional wisdom has it that the knowledge worker will re...
#   - [9] DISTRACTOR score=0.4405 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [15] DISTRACTOR score=0.4277 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [3] DISTRACTOR score=0.4057 | toyota makes major investment in artificial intelligence the japanese automaker is pouring...
#
# Query: what does big data have to do with artificial intelligence hype
#   Gold rank: 3
#   Distractors above gold: 2
#   - [10] DISTRACTOR score=0.9785 | what your data scientist wishes you knew by daniel wesley big data it s the topic on every...
#   - [25] DISTRACTOR score=0.9455 | big data and deep learning big deals or big delusions getting the most out deep learning w...
#   - [30] GOLD score=0.7925 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#   - [17] DISTRACTOR score=0.7858 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [19] DISTRACTOR score=0.5741 | is an ai arms race inevitable unlike nuclear weapons this new class can potentially target...
# ===== DEFENDED DENSE RESULTS =====
#
# Query: why are business leaders worried about artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [7] GOLD score=1.0000 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [33] DISTRACTOR score=0.6524 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#   - [17] DISTRACTOR score=0.5316 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [12] DISTRACTOR score=0.4339 | why automation will create not destroy jobs if you have been watching political tectonics ...
#   - [30] DISTRACTOR score=0.4256 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#
# Query: can artificial intelligence predict autism in babies
#   Gold rank: 1
#   Distractors above gold: 0
#   - [14] GOLD score=1.0000 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [1] DISTRACTOR score=0.3656 | this groundbreaking algorithm can spot sepsis before doctors five ways artificial intellig...
#   - [29] DISTRACTOR score=0.3185 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [5] DISTRACTOR score=0.2571 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [33] DISTRACTOR score=0.2279 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#
# Query: why do siri and other digital assistants use female voices
#   Gold rank: 1
#   Distractors above gold: 0
#   - [22] GOLD score=1.0000 | why are digital assistants like siri given female voices at an artificial intelligence con...
#   - [4] DISTRACTOR score=0.2047 | preparing to live in that unknown country the future are google s driverless car and siri ...
#   - [21] DISTRACTOR score=0.1697 | robots will replace 5 million workers by 2020 report automation promises to make many admi...
#   - [33] DISTRACTOR score=0.1675 | artificial intelligence might just disrupt know it all white men robots will likely termin...
#   - [26] DISTRACTOR score=0.1205 | this ai robot shading chrissy teigen makes us fear for humanity it was nice knowing you ch...
#
# Query: what is facebook doing to build an artificial brain
#   Gold rank: 1
#   Distractors above gold: 0
#   - [29] GOLD score=0.9983 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [14] DISTRACTOR score=0.2733 | ai predicts autism based on infant brain scans it was extremely accurate...
#   - [2] DISTRACTOR score=0.2056 | we should make ai and blockchain boost global trade it is time to build an intelligent tec...
#   - [9] DISTRACTOR score=0.1749 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [15] DISTRACTOR score=0.1708 | artificial intelligence is here to change your life the revolution began before you even r...
#
# Query: how is microsoft describing the benefits of artificial intelligence
#   Gold rank: 1
#   Distractors above gold: 0
#   - [5] GOLD score=1.0000 | artificial intelligence is here to help us microsoft boss jean philippe courtois says we c...
#   - [9] DISTRACTOR score=0.5318 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [17] DISTRACTOR score=0.4654 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [30] DISTRACTOR score=0.4284 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#   - [15] DISTRACTOR score=0.3183 | artificial intelligence is here to change your life the revolution began before you even r...
#
# Query: how is artificial intelligence expected to change daily life
#   Gold rank: None
#   Distractors above gold: 5
#   - [15] DISTRACTOR score=1.0000 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [9] DISTRACTOR score=0.4768 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [17] DISTRACTOR score=0.3802 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [31] DISTRACTOR score=0.3531 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [27] DISTRACTOR score=0.3253 | ai day will replace christmas as the most important holiday in less than 25 years some rel...
#
# Query: what breakthrough did google make in the game of go using ai
#   Gold rank: 1
#   Distractors above gold: 0
#   - [8] GOLD score=0.9985 | in a huge breakthrough google s ai beats a top player at the game of go in a major breakth...
#   - [28] DISTRACTOR score=0.8296 | how google s ai beat a human at go a decade earlier than expected last week news broke tha...
#   - [32] DISTRACTOR score=0.5960 | google s alphago ai program defeats one of world s best go players this is huge...
#   - [0] DISTRACTOR score=0.4849 | human player finally beats google s alphago ai program at go it was fourth time lucky for ...
#   - [36] DISTRACTOR score=0.2860 | google just open sourced its artificial intelligence engine tech pundit tim o reilly had j...
#
# Query: how could ai change love and relationships
#   Gold rank: 1
#   Distractors above gold: 0
#   - [9] GOLD score=0.9342 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [31] DISTRACTOR score=0.6017 | how to stop worrying and love artificial intelligence a new book finds the heart in our co...
#   - [15] DISTRACTOR score=0.5957 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [29] DISTRACTOR score=0.2524 | inside facebook s plan to build an artificial brain the beauty of ai systems is that we ca...
#   - [27] DISTRACTOR score=0.2387 | ai day will replace christmas as the most important holiday in less than 25 years some rel...
#
# Query: why is artificial intelligence technology said to be breaking out of the box
#   Gold rank: 1
#   Distractors above gold: 0
#   - [17] GOLD score=1.0000 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [9] DISTRACTOR score=0.3430 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...
#   - [15] DISTRACTOR score=0.3256 | artificial intelligence is here to change your life the revolution began before you even r...
#   - [7] DISTRACTOR score=0.3098 | world s business elite are stressed about our robotic future in davos not everyone is exci...
#   - [13] DISTRACTOR score=0.3025 | the rise of the wisdom worker conventional wisdom has it that the knowledge worker will re...
#
# Query: what does big data have to do with artificial intelligence hype
#   Gold rank: 3
#   Distractors above gold: 2
#   - [10] DISTRACTOR score=0.9486 | what your data scientist wishes you knew by daniel wesley big data it s the topic on every...
#   - [25] DISTRACTOR score=0.9179 | big data and deep learning big deals or big delusions getting the most out deep learning w...
#   - [30] GOLD score=0.8616 | amazon is making it easier for companies to track you by adrienne lafrance like big data a...
#   - [17] DISTRACTOR score=0.7748 | artificial intelligence technology is breaking out of the box the exponential improvement ...
#   - [9] DISTRACTOR score=0.4731 | how ai will redefine love artificial intelligence is beginning to disrupt entire industrie...

# %%
# =========================================
# 15. GOLD DOCUMENT RANK TESTS
# =========================================

print("\n===== GOLD DOCUMENT RANK TEST: DENSE vs DEFENDED DENSE =====")
for query, gold_idx in query_gold_pairs:
    dense_results = retrieve_topk_precomputed(
        query, docs_corpus, doc_emb_corpus, k=10
    )
    defended_results = retrieve_defended_dense(
        query,
        docs_corpus,
        doc_emb_corpus,
        bm25_corpus,
        tfidf_matrix_corpus,
        tfidf_vectorizer,
        top_n=20,
        k=10
    )

    dense_rank = get_rank_of_doc(dense_results, gold_idx)
    defended_rank = get_rank_of_doc(defended_results, gold_idx)

    print("\nQuery:", query)
    print("Gold document index:", gold_idx)
    print("Rank in Dense:", dense_rank)
    print("Rank in Defended Dense:", defended_rank)

print("\n===== GOLD DOCUMENT RANK TEST: BM25 =====")
for query, gold_idx in query_gold_pairs:
    bm25_results = retrieve_bm25(
        query, docs_corpus, bm25_corpus, k=10
    )
    bm25_rank = get_rank_of_doc(bm25_results, gold_idx)

    print("\nQuery:", query)
    print("Gold document index:", gold_idx)
    print("Rank in BM25:", bm25_rank)

print("\n===== GOLD DOCUMENT RANK TEST: TF-IDF =====")
for query, gold_idx in query_gold_pairs:
    tfidf_results = retrieve_tfidf(
        query, docs_corpus, tfidf_matrix_corpus, tfidf_vectorizer, k=10
    )
    tfidf_rank = get_rank_of_doc(tfidf_results, gold_idx)

    print("\nQuery:", query)
    print("Gold document index:", gold_idx)
    print("Rank in TF-IDF:", tfidf_rank)

print("\n===== GOLD DOCUMENT RANK TEST: HYBRID =====")
for query, gold_idx in query_gold_pairs:
    hybrid_results = retrieve_hybrid(
        query, docs_corpus, doc_emb_corpus, bm25_corpus, k=10, alpha=0.5
    )
    hybrid_rank = get_rank_of_doc(hybrid_results, gold_idx)

    print("\nQuery:", query)
    print("Gold document index:", gold_idx)
    print("Rank in Hybrid:", hybrid_rank)
# Out:
# ===== GOLD DOCUMENT RANK TEST: DENSE vs DEFENDED DENSE =====
#
# Query: why are business leaders worried about artificial intelligence
# Gold document index: 7
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: can artificial intelligence predict autism in babies
# Gold document index: 14
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: why do siri and other digital assistants use female voices
# Gold document index: 22
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: what is facebook doing to build an artificial brain
# Gold document index: 29
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: how is microsoft describing the benefits of artificial intelligence
# Gold document index: 5
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: how is artificial intelligence expected to change daily life
# Gold document index: 1
# Rank in Dense: None
# Rank in Defended Dense: None
#
# Query: what breakthrough did google make in the game of go using ai
# Gold document index: 8
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: how could ai change love and relationships
# Gold document index: 9
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: why is artificial intelligence technology said to be breaking out of the box
# Gold document index: 17
# Rank in Dense: 1
# Rank in Defended Dense: 1
#
# Query: what does big data have to do with artificial intelligence hype
# Gold document index: 30
# Rank in Dense: 1
# Rank in Defended Dense: 3
#
# ===== GOLD DOCUMENT RANK TEST: BM25 =====
#
# Query: why are business leaders worried about artificial intelligence
# Gold document index: 7
# Rank in BM25: 1
#
# Query: can artificial intelligence predict autism in babies
# Gold document index: 14
# Rank in BM25: 1
#
# Query: why do siri and other digital assistants use female voices
# Gold document index: 22
# Rank in BM25: 1
#
# Query: what is facebook doing to build an artificial brain
# Gold document index: 29
# Rank in BM25: 1
#
# Query: how is microsoft describing the benefits of artificial intelligence
# Gold document index: 5
# Rank in BM25: 1
#
# Query: how is artificial intelligence expected to change daily life
# Gold document index: 1
# Rank in BM25: None
#
# Query: what breakthrough did google make in the game of go using ai
# Gold document index: 8
# Rank in BM25: 1
#
# Query: how could ai change love and relationships
# Gold document index: 9
# Rank in BM25: 2
#
# Query: why is artificial intelligence technology said to be breaking out of the box
# Gold document index: 17
# Rank in BM25: 1
#
# Query: what does big data have to do with artificial intelligence hype
# Gold document index: 30
# Rank in BM25: 6
#
# ===== GOLD DOCUMENT RANK TEST: TF-IDF =====
#
# Query: why are business leaders worried about artificial intelligence
# Gold document index: 7
# Rank in TF-IDF: 1
#
# Query: can artificial intelligence predict autism in babies
# Gold document index: 14
# Rank in TF-IDF: 1
#
# Query: why do siri and other digital assistants use female voices
# Gold document index: 22
# Rank in TF-IDF: 1
#
# Query: what is facebook doing to build an artificial brain
# Gold document index: 29
# Rank in TF-IDF: 1
#
# Query: how is microsoft describing the benefits of artificial intelligence
# Gold document index: 5
# Rank in TF-IDF: 1
#
# Query: how is artificial intelligence expected to change daily life
# Gold document index: 1
# Rank in TF-IDF: 6
#
# Query: what breakthrough did google make in the game of go using ai
# Gold document index: 8
# Rank in TF-IDF: 1
#
# Query: how could ai change love and relationships
# Gold document index: 9
# Rank in TF-IDF: 2
#
# Query: why is artificial intelligence technology said to be breaking out of the box
# Gold document index: 17
# Rank in TF-IDF: 1
#
# Query: what does big data have to do with artificial intelligence hype
# Gold document index: 30
# Rank in TF-IDF: 3
#
# ===== GOLD DOCUMENT RANK TEST: HYBRID =====
#
# Query: why are business leaders worried about artificial intelligence
# Gold document index: 7
# Rank in Hybrid: 1
#
# Query: can artificial intelligence predict autism in babies
# Gold document index: 14
# Rank in Hybrid: 1
#
# Query: why do siri and other digital assistants use female voices
# Gold document index: 22
# Rank in Hybrid: 1
#
# Query: what is facebook doing to build an artificial brain
# Gold document index: 29
# Rank in Hybrid: 1
#
# Query: how is microsoft describing the benefits of artificial intelligence
# Gold document index: 5
# Rank in Hybrid: 1
#
# Query: how is artificial intelligence expected to change daily life
# Gold document index: 1
# Rank in Hybrid: None
#
# Query: what breakthrough did google make in the game of go using ai
# Gold document index: 8
# Rank in Hybrid: 1
#
# Query: how could ai change love and relationships
# Gold document index: 9
# Rank in Hybrid: 1
#
# Query: why is artificial intelligence technology said to be breaking out of the box
# Gold document index: 17
# Rank in Hybrid: 1
#
# Query: what does big data have to do with artificial intelligence hype
# Gold document index: 30
# Rank in Hybrid: 3

# %%
# =========================================
# 16. RETRIEVAL METRICS: HIT@10, MRR@10, DISTRACTORS ABOVE GOLD
# =========================================

print("\n===== RETRIEVAL METRICS =====")

evaluation_summary = {}

evaluation_summary["Dense"] = evaluate_single_method(
    query_gold_pairs,
    retrieve_fn=lambda q: retrieve_topk_precomputed(
        q, docs_corpus, doc_emb_corpus, K_EVALUATION
    ),
    k=K_EVALUATION
)

evaluation_summary["BM25"] = evaluate_single_method(
    query_gold_pairs,
    retrieve_fn=lambda q: retrieve_bm25(
        q, docs_corpus, bm25_corpus, K_EVALUATION
    ),
    k=K_EVALUATION
)

evaluation_summary["TF-IDF"] = evaluate_single_method(
    query_gold_pairs,
    retrieve_fn=lambda q: retrieve_tfidf(
        q, docs_corpus, tfidf_matrix_corpus, tfidf_vectorizer, K_EVALUATION
    ),
    k=K_EVALUATION
)

evaluation_summary["Hybrid"] = evaluate_single_method(
    query_gold_pairs,
    retrieve_fn=lambda q: retrieve_hybrid(
        q, docs_corpus, doc_emb_corpus, bm25_corpus, K_EVALUATION, alpha=0.5
    ),
    k=K_EVALUATION
)

evaluation_summary["DefendedDense"] = evaluate_single_method(
    query_gold_pairs,
    retrieve_fn=lambda q: retrieve_defended_dense(
        q,
        docs_corpus,
        doc_emb_corpus,
        bm25_corpus,
        tfidf_matrix_corpus,
        tfidf_vectorizer,
        top_n=20,
        k=K_EVALUATION
    ),
    k=K_EVALUATION
)

for method_name, metrics in evaluation_summary.items():
    print(f"\n{method_name}")
    print(f"  Hit@10: {metrics['Hit@10']:.4f}")
    print(f"  MRR@10: {metrics['MRR@10']:.4f}")
    print(f"  Avg Distractors Above Gold: {metrics['Avg Distractors Above Gold']:.4f}")
# Out:
# ===== RETRIEVAL METRICS =====
#
# Dense
#   Hit@10: 0.9000
#   MRR@10: 0.9000
#   Avg Distractors Above Gold: 1.0000
#
# BM25
#   Hit@10: 0.9000
#   MRR@10: 0.7667
#   Avg Distractors Above Gold: 1.6000
#
# TF-IDF
#   Hit@10: 1.0000
#   MRR@10: 0.8000
#   Avg Distractors Above Gold: 0.8000
#
# Hybrid
#   Hit@10: 0.9000
#   MRR@10: 0.8333
#   Avg Distractors Above Gold: 1.2000
#
# DefendedDense
#   Hit@10: 0.9000
#   MRR@10: 0.8333
#   Avg Distractors Above Gold: 1.2000

# %%
# =========================================
# 17. METRIC VISUALIZATIONS
# =========================================

metric_names = ["Hit@10", "MRR@10", "Avg Distractors Above Gold"]
method_names_metrics = list(evaluation_summary.keys())

for metric in metric_names:
    values = [evaluation_summary[m][metric] for m in method_names_metrics]

    plt.figure()
    plt.bar(method_names_metrics, values)

    if metric in ["Hit@10", "MRR@10"]:
        plt.ylim(0, 1)
    else:
        plt.ylim(0, K_EVALUATION)

    plt.xlabel("Retrieval Method")
    plt.ylabel(metric)
    plt.title(f"{metric} Comparison Across Methods")
    plt.show()

# %%
# =========================================
# 18. METHOD COMPARISON USING DISTRACTORS ABOVE GOLD
# =========================================

methods = {
    "Dense": lambda q: retrieve_topk_precomputed(q, docs_corpus, doc_emb_corpus, K_DISTRACTOR_ANALYSIS),
    "BM25": lambda q: retrieve_bm25(q, docs_corpus, bm25_corpus, K_DISTRACTOR_ANALYSIS),
    "TF-IDF": lambda q: retrieve_tfidf(q, docs_corpus, tfidf_matrix_corpus, tfidf_vectorizer, K_DISTRACTOR_ANALYSIS),
    "Hybrid": lambda q: retrieve_hybrid(q, docs_corpus, doc_emb_corpus, bm25_corpus, K_DISTRACTOR_ANALYSIS, alpha=0.5),
    "DefendedDense": lambda q: retrieve_defended_dense(
        q,
        docs_corpus,
        doc_emb_corpus,
        bm25_corpus,
        tfidf_matrix_corpus,
        tfidf_vectorizer,
        top_n=20,
        k=K_DISTRACTOR_ANALYSIS
    ),
}

print("===== METHOD COMPARISON =====")
for method_name, method_fn in methods.items():
    print(f"\n{method_name}")
    for q, gold_idx in query_gold_pairs:
        results = method_fn(q)
        distractor_hits = count_distractors_above_gold(results, gold_idx)
        gold_rank = get_rank_of_doc(results, gold_idx)
        print(f"  {q} -> Gold rank: {gold_rank}, Distractors above gold: {distractor_hits}")

# =========================================
# 19. AUTOMATIC DISTRACTOR-ABOVE-GOLD PLOTS
# =========================================

method_results = {}

for method_name, method_fn in methods.items():
    distractor_list = []
    for q, gold_idx in query_gold_pairs:
        results = method_fn(q)
        distractor_hits = count_distractors_above_gold(results, gold_idx)
        distractor_list.append(distractor_hits)
    method_results[method_name] = distractor_list

print("Computed distractors-above-gold automatically:")
for method_name, distractor_list in method_results.items():
    print(method_name, "->", distractor_list)

# Average distractors above gold per method
method_names = list(method_results.keys())
avg_scores = [np.mean(method_results[m]) for m in method_names]

plt.figure()
plt.bar(method_names, avg_scores)
plt.xlabel("Retrieval Method")
plt.ylabel("Average Distractors Above Gold")
plt.title("Comparison of Retrieval Methods by Distractors Above Gold")
plt.show()

# Distractors above gold per query for each method
queries_labels = [f"Q{i+1}" for i in range(len(query_gold_pairs))]
x = np.arange(len(queries_labels))
width = 0.16

plt.figure()
for i, method_name in enumerate(method_names):
    plt.bar(
        x + (i - (len(method_names)-1)/2) * width,
        method_results[method_name],
        width,
        label=method_name
    )

plt.xticks(x, queries_labels)
plt.xlabel("Queries")
plt.ylabel("Distractors Above Gold")
plt.title("Distractors Above Gold Across Queries")
plt.legend()
plt.show()
# Out:
# ===== METHOD COMPARISON =====
#
# Dense
#   why are business leaders worried about artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   can artificial intelligence predict autism in babies -> Gold rank: 1, Distractors above gold: 0
#   why do siri and other digital assistants use female voices -> Gold rank: 1, Distractors above gold: 0
#   what is facebook doing to build an artificial brain -> Gold rank: 1, Distractors above gold: 0
#   how is microsoft describing the benefits of artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   how is artificial intelligence expected to change daily life -> Gold rank: None, Distractors above gold: 5
#   what breakthrough did google make in the game of go using ai -> Gold rank: 1, Distractors above gold: 0
#   how could ai change love and relationships -> Gold rank: 1, Distractors above gold: 0
#   why is artificial intelligence technology said to be breaking out of the box -> Gold rank: 1, Distractors above gold: 0
#   what does big data have to do with artificial intelligence hype -> Gold rank: 1, Distractors above gold: 0
#
# BM25
#   why are business leaders worried about artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   can artificial intelligence predict autism in babies -> Gold rank: 1, Distractors above gold: 0
#   why do siri and other digital assistants use female voices -> Gold rank: 1, Distractors above gold: 0
#   what is facebook doing to build an artificial brain -> Gold rank: 1, Distractors above gold: 0
#   how is microsoft describing the benefits of artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   how is artificial intelligence expected to change daily life -> Gold rank: None, Distractors above gold: 5
#   what breakthrough did google make in the game of go using ai -> Gold rank: 1, Distractors above gold: 0
#   how could ai change love and relationships -> Gold rank: 2, Distractors above gold: 1
#   why is artificial intelligence technology said to be breaking out of the box -> Gold rank: 1, Distractors above gold: 0
#   what does big data have to do with artificial intelligence hype -> Gold rank: None, Distractors above gold: 5
#
# TF-IDF
#   why are business leaders worried about artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   can artificial intelligence predict autism in babies -> Gold rank: 1, Distractors above gold: 0
#   why do siri and other digital assistants use female voices -> Gold rank: 1, Distractors above gold: 0
#   what is facebook doing to build an artificial brain -> Gold rank: 1, Distractors above gold: 0
#   how is microsoft describing the benefits of artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   how is artificial intelligence expected to change daily life -> Gold rank: None, Distractors above gold: 5
#   what breakthrough did google make in the game of go using ai -> Gold rank: 1, Distractors above gold: 0
#   how could ai change love and relationships -> Gold rank: 2, Distractors above gold: 1
#   why is artificial intelligence technology said to be breaking out of the box -> Gold rank: 1, Distractors above gold: 0
#   what does big data have to do with artificial intelligence hype -> Gold rank: 3, Distractors above gold: 2
#
# Hybrid
#   why are business leaders worried about artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   can artificial intelligence predict autism in babies -> Gold rank: 1, Distractors above gold: 0
#   why do siri and other digital assistants use female voices -> Gold rank: 1, Distractors above gold: 0
#   what is facebook doing to build an artificial brain -> Gold rank: 1, Distractors above gold: 0
#   how is microsoft describing the benefits of artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   how is artificial intelligence expected to change daily life -> Gold rank: None, Distractors above gold: 5
#   what breakthrough did google make in the game of go using ai -> Gold rank: 1, Distractors above gold: 0
#   how could ai change love and relationships -> Gold rank: 1, Distractors above gold: 0
#   why is artificial intelligence technology said to be breaking out of the box -> Gold rank: 1, Distractors above gold: 0
#   what does big data have to do with artificial intelligence hype -> Gold rank: 3, Distractors above gold: 2
#
# DefendedDense
#   why are business leaders worried about artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   can artificial intelligence predict autism in babies -> Gold rank: 1, Distractors above gold: 0
#   why do siri and other digital assistants use female voices -> Gold rank: 1, Distractors above gold: 0
#   what is facebook doing to build an artificial brain -> Gold rank: 1, Distractors above gold: 0
#   how is microsoft describing the benefits of artificial intelligence -> Gold rank: 1, Distractors above gold: 0
#   how is artificial intelligence expected to change daily life -> Gold rank: None, Distractors above gold: 5
#   what breakthrough did google make in the game of go using ai -> Gold rank: 1, Distractors above gold: 0
#   how could ai change love and relationships -> Gold rank: 1, Distractors above gold: 0
#   why is artificial intelligence technology said to be breaking out of the box -> Gold rank: 1, Distractors above gold: 0
#   what does big data have to do with artificial intelligence hype -> Gold rank: 3, Distractors above gold: 2
# Computed distractors-above-gold automatically:
# Dense -> [0, 0, 0, 0, 0, 5, 0, 0, 0, 0]
# BM25 -> [0, 0, 0, 0, 0, 5, 0, 1, 0, 5]
# TF-IDF -> [0, 0, 0, 0, 0, 5, 0, 1, 0, 2]
# Hybrid -> [0, 0, 0, 0, 0, 5, 0, 0, 0, 2]
# DefendedDense -> [0, 0, 0, 0, 0, 5, 0, 0, 0, 2]

# %%
# =========================================
# 20. FINAL SUMMARY
# =========================================

print("\n===== FINAL SUMMARY =====")
print("This notebook evaluates retrieval robustness using real distractor documents from the dataset.")
print("We compared Dense, BM25, TF-IDF, Hybrid, and Defended Dense retrieval.")
print("We measured:")
print("1. Gold document rank across retrieval methods")
print("2. Hit@10 and MRR@10 for each method")
print("3. Average number of distractors ranked above the gold document")
print("These results show how retrieval methods behave when semantically similar but non-gold real documents compete with the correct result.")
print("The defended reranking method combines semantic and lexical signals to reduce distractors above the gold document and improve retrieval robustness.")
# Out:
# ===== FINAL SUMMARY =====
# This notebook evaluates retrieval robustness using real distractor documents from the dataset.
# We compared Dense, BM25, TF-IDF, Hybrid, and Defended Dense retrieval.
# We measured:
# 1. Gold document rank across retrieval methods
# 2. Hit@10 and MRR@10 for each method
# 3. Average number of distractors ranked above the gold document
# These results show how retrieval methods behave when semantically similar but non-gold real documents compete with the correct result.
# The defended reranking method combines semantic and lexical signals to reduce distractors above the gold document and improve retrieval robustness.
